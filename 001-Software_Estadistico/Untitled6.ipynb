# %%
dim(ocr)

# %%
require(graphics)

table <- expand.grid(1:200,1:40)
table <-cbind(table[1],table[2],(c(ocr[,-41])))
df<- data.frame(table)

contour(table[1],table[2],table[3])
# Out:
# Error in contour.default(table[1], table[2], table[3]): no proper 'z' matrix specified
# Traceback:
#
# 1. contour(table[1], table[2], table[3])
# 2. contour.default(table[1], table[2], table[3])
# 3. stop("no proper 'z' matrix specified")

# %% [raw]
# class(df)
# class(as.matrix(df))
# is.numeric(as.matrix(df[3]))

# %%
class(2)
class(c(ocr)[1])
is.numeric(class(c(ocr)[1]))
# Out:
# [1] "numeric"
# [1] "numeric"
# [1] FALSE

# %%
length(c(ocr[,-41]))
# Out:
# [1] 8000

# %%
## contourLines produces the same contour lines as contour
plot(x = 0, y = 0, type = "n", xlim = rx, ylim = ry, xlab = "", ylab = "")
u <- par("usr")
rect(u[1], u[3], u[2], u[4], col = tcol[8], border = "red")
contour(x, y, volcano, col = tcol[1], lty = "solid", add = TRUE,
        vfont = c("sans serif", "plain"))
line.list <- contourLines(x, y, volcano)
invisible(lapply(line.list, lines, lwd=3, col=adjustcolor(2, .3)))
par(opar)
# Out:
# Error in plot.default(x = 0, y = 0, type = "n", xlim = rx, ylim = ry, : objeto 'rx' no encontrado
# Traceback:
#
# 1. plot(x = 0, y = 0, type = "n", xlim = rx, ylim = ry, xlab = "",
#  .     ylab = "")
# 2. plot.default(x = 0, y = 0, type = "n", xlim = rx, ylim = ry,
#  .     xlab = "", ylab = "")

# %%
require(grDevices) # for colours
x <- -6:16
op <- par(mfrow = c(2, 2))
contour(outer(x, x), method = "edge", vfont = c("sans serif", "plain"))
z <- outer(x, sqrt(abs(x)), FUN = "/")
image(x, x, z)
contour(x, x, z, col = "pink", add = TRUE, method = "edge",
        vfont = c("sans serif", "plain"))
contour(x, x, z, ylim = c(1, 6), method = "simple", labcex = 1,
        xlab = quote(x[1]), ylab = quote(x[2]))
contour(x, x, z, ylim = c(-6, 6), nlev = 20, lty = 2, method = "simple",
        main = "20 levels; \"simple\" labelling method")
par(op)

## Persian Rug Art:
x <- y <- seq(-4*pi, 4*pi, len = 27)
r <- sqrt(outer(x^2, y^2, "+"))
opar <- par(mfrow = c(2, 2), mar = rep(0, 4))
for(f in pi^(0:3))
  contour(cos(r^2)*exp(-r/f),
          drawlabels = FALSE, axes = FALSE, frame = TRUE)

rx <- range(x <- 10*1:nrow(volcano))
ry <- range(y <- 10*1:ncol(volcano))
ry <- ry + c(-1, 1) * (diff(rx) - diff(ry))/2
tcol <- terrain.colors(12)
par(opar); opar <- par(pty = "s", bg = "lightcyan")
plot(x = 0, y = 0, type = "n", xlim = rx, ylim = ry, xlab = "", ylab = "")
u <- par("usr")
rect(u[1], u[3], u[2], u[4], col = tcol[8], border = "red")
contour(x, y, volcano, col = tcol[2], lty = "solid", add = TRUE,
        vfont = c("sans serif", "plain"))
title("A Topographic Map of Maunga Whau", font = 4)
abline(h = 200*0:4, v = 200*0:4, col = "lightgray", lty = 2, lwd = 0.1)

## contourLines produces the same contour lines as contour
plot(x = 0, y = 0, type = "n", xlim = rx, ylim = ry, xlab = "", ylab = "")
u <- par("usr")
rect(u[1], u[3], u[2], u[4], col = tcol[8], border = "red")
contour(x, y, volcano, col = tcol[1], lty = "solid", add = TRUE,
        vfont = c("sans serif", "plain"))
line.list <- contourLines(x, y, volcano)
invisible(lapply(line.list, lines, lwd=3, col=adjustcolor(2, .3)))
par(opar)
# Out:
# Plot with title “20 levels; "simple" labelling method”
# plot without title
# Plot with title “A Topographic Map of Maunga Whau”
# plot without title

# %%
image(as.matrix(df), col=gray.colors(n, start = 0.3, end = 0.9, gamma = 2.2, alpha = NULL)
, axes=FALSE, 
        xlab="Objetos", ylab="Objetos", main="Método=Euclidean")
# Out:
# Plot with title “Método=Euclidean”
